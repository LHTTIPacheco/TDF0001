# %% [markdown]
# # Descrição dos dados
#
# Conjunto de dados fornecidos pela competição "Housing Prices Competition" da Kaggle (https://www.kaggle.com/c/home-data-for-ml-course/overview). Neste banco de dados estão contidos registros de 80 variáveis que descrevem as características de residências da região de Ames, Iowa, nos EUA.
# </br>As descrições das variáveis podem ser acessadas por meio do arquivo "data_description.txt". O conjunto está separado em dois arquivos ".csv", um conjunto de treino e um conjunto de teste. Os dados de teste não possuem a variável alvo "SalePrice".
#
# Objetivo geral: predizer a variável "SalePrice" utilizando as outras 79 variáveis contidas no conjunto de dados.
#
# Objetivos específicos:
# 1.   Importação e análise exploratória dos dados;
# 2.   Pré tratamento;
# 3.   Feature Engineering e Feature Selection;
# 4.   Criação, treinamento e avaliação de modelos lineares de aprendizagem de máquina.
#
# Pasta compartilhada: https://drive.google.com/drive/folders/13Scy1GEuxH1MSmsWDfWMnLEjDcTkYKy7?usp=sharing

# %% [markdown]
# # Importação de bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Carregamento dos dados

# %%
from google.colab import files

# %%
a = !ls
# Out:
# ['sample_data']

# %%
#file_path = '/content/train.csv'
#data = pd.read_csv(file_path, index_col = 'Id')

file_url = 'https://raw.githubusercontent.com/LHTTIPacheco/TDF0001/master/Grupo2/dados/train.csv'
data_url = pd.read_csv(file_url,index_col = 'Id')
data_url.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# Id                                    ...
# 1           60       RL         65.0  ...        WD        Normal    208500
# 2           20       RL         80.0  ...        WD        Normal    181500
# 3           60       RL         68.0  ...        WD        Normal    223500
# 4           70       RL         60.0  ...        WD       Abnorml    140000
# 5           60       RL         84.0  ...        WD        Normal    250000
#
# [5 rows x 80 columns]

# %% [markdown]
# # Análise exploratória

# %%
data.describe()
# Out:
#         MSSubClass  LotFrontage  ...       YrSold      SalePrice
# count  1460.000000  1201.000000  ...  1460.000000    1460.000000
# mean     56.897260    70.049958  ...  2007.815753  180921.195890
# std      42.300571    24.284752  ...     1.328095   79442.502883
# min      20.000000    21.000000  ...  2006.000000   34900.000000
# 25%      20.000000    59.000000  ...  2007.000000  129975.000000
# 50%      50.000000    69.000000  ...  2008.000000  163000.000000
# 75%      70.000000    80.000000  ...  2009.000000  214000.000000
# max     190.000000   313.000000  ...  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %%
data.describe(exclude = ['int64', 'float64'])
# Out:
#        MSZoning Street Alley LotShape  ...  Fence MiscFeature SaleType SaleCondition
# count      1460   1460    91     1460  ...    281          54     1460          1460
# unique        5      2     2        4  ...      4           4        9             6
# top          RL   Pave  Grvl      Reg  ...  MnPrv        Shed       WD        Normal
# freq       1151   1454    50      925  ...    157          49     1267          1198
#
# [4 rows x 43 columns]

# %%
# Configurações de plotagem
plt.rcParams.update({
    'font.size': 11,
    'xtick.color': 'white',
    'ytick.color': 'white',
    'axes.labelcolor': 'white',
    'axes.titlecolor': 'white',
    'axes.titlesize': 20,
    'figure.figsize': (25,6)
})

# %%
is_missing = data.isnull()
sns.heatmap(is_missing)

# %%
data['LotFrontage'].isnull().value_counts()
# Out:
# False    1201
# True      259
# Name: LotFrontage, dtype: int64

# %%
data.drop(labels=['Alley','LotFrontage','FireplaceQu','PoolQC','Fence', 'MiscFeature'],inplace=True,axis=1)

# %%
is_missing = data.isnull()
sns.heatmap(is_missing)

# %%
sns.violinplot(x=data['MasVnrType'],y=data['SalePrice'])

# %%
data.isnull().sum()[data.isnull().sum() != 0]

# %%
data_null = data[pd.DataFrame(data.isnull().sum()[data.isnull().sum() != 0]).index]
data_null['MasVnrArea'][data_null['MasVnrArea'].isnull()]
# Out:
# Id
# 235    NaN
# 530    NaN
# 651    NaN
# 937    NaN
# 974    NaN
# 978    NaN
# 1244   NaN
# 1279   NaN
# Name: MasVnrArea, dtype: float64

# %%
data_null.describe(exclude=['int64','float64'])
# Out:
#        MasVnrType BsmtQual BsmtCond  ... GarageFinish GarageQual GarageCond
# count        1452     1423     1423  ...         1379       1379       1379
# unique          4        4        4  ...            3          5          5
# top          None       TA       TA  ...          Unf         TA         TA
# freq          864      649     1311  ...          605       1311       1326
#
# [4 rows x 11 columns]

# %%
data2 = data.copy()

# %%
columns_categorical=data_null.select_dtypes(exclude=['int64','float64']).columns
columns_categorical
# Out:
# Index(['MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Electrical', 'GarageType', 'GarageFinish',
#        'GarageQual', 'GarageCond'],
#       dtype='object')

# %%
for i in range(11):
  plt.figure(figsize=(15,100))
  plt.subplot(11,1,i+1)
  sns.violinplot(data=data, x=columns_categorical[i], y='SalePrice')
  plt.title(columns_categorical[i])

# %%
data_null.select_dtypes(exclude=['int64','float64'])
# Out:
#      MasVnrType BsmtQual BsmtCond  ... GarageFinish GarageQual GarageCond
# Id                                 ...
# 1       BrkFace       Gd       TA  ...          RFn         TA         TA
# 2          None       Gd       TA  ...          RFn         TA         TA
# 3       BrkFace       Gd       TA  ...          RFn         TA         TA
# 4          None       TA       Gd  ...          Unf         TA         TA
# 5       BrkFace       Gd       TA  ...          RFn         TA         TA
# ...         ...      ...      ...  ...          ...        ...        ...
# 1456       None       Gd       TA  ...          RFn         TA         TA
# 1457      Stone       Gd       TA  ...          Unf         TA         TA
# 1458       None       TA       Gd  ...          RFn         TA         TA
# 1459       None       TA       TA  ...          Unf         TA         TA
# 1460       None       TA       TA  ...          Fin         TA         TA
#
# [1460 rows x 11 columns]

# %%
from sklearn.impute import SimpleImputer

# %%
for col in columns_categorical:
    data2[col].fillna(data2[col].mode()[0],inplace=True)

# %%
display(data2[columns_categorical].isnull().sum())
# Out:
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Electrical      0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# dtype: int64

# %%
is_missing = data2.isnull()
sns.heatmap(is_missing)

# %%
data2['GarageYrBlt'].fillna(data2['GarageYrBlt'].mode()[0],inplace=True)

# %%
data2[data2['MasVnrType'] == 'None']['MasVnrArea'] = 0
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data2[data_null.columns].isnull().sum()
# Out:
# MasVnrType      0
# MasVnrArea      8
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Electrical      0
# GarageType      0
# GarageYrBlt     0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# dtype: int64
